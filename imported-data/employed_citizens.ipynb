# %%
import json
import urllib.request as request

# %%
url = 'http://dadosabertos.dataprev.gov.br/opendata/ctb01/formato=json'

# %%
content = request.urlopen(url).read()

# %%
data = json.loads(content.decode('latin-1'))

# %%
len(data['nodes'])
# Out:
# 246873

# %%
data['nodes']
# Out:
# [{'node': {'Ano': '1995',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1316998',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1113938',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '50697',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '970459',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '601812',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '30998',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '129249',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '763930',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '19054',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '94191',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '167643',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '2411',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '69398',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '50133',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '5582',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '11162',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '5829',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '113',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '17743',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '6517',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '114',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '84905',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '146678',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1995',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '491213',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '0,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1317633',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '305844770,90',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1134364',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '222725614,95',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '40943',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '7236444,96',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '907437',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '294113095,52',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '577126',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '133987022,61',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '24256',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '5086470,60',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '132470',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '34785833,32',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '867492',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '173398091,09',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '13007',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '2620382,40',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '111755',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '31500240,13',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '202602',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '37405650,86',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '2572',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '530642,88',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '63741',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '16953585,12',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '46261',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '10837905,84',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '4769',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '1109974,32',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '10033',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '1091246,04',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '5318',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '387858,24',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '99',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '9703,80',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '18191',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '3478503,96',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '7501',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '1219343,76',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '116',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '20986,56',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '110967',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '25735467,98',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '195266',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '36377034,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1996',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '492805',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '145397957,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1287981',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '443382853,07',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1117278',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '332549224,75',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '13947',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '4425200,53',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '950150',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '420983252,92',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '596219',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '196442722,83',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '8067',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '3172311,00',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '149044',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '46521434,39',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1041740',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '253104177,78',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '10837',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '2961268,88',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '165774',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '63111035,03',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '250763',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '72751195,50',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '4253',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '1444979,33',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '56261',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '12942700,72',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '84408',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '17521313,69',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1409',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '325799,67',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '9904',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '2081966,93',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '4581',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '649859,55',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '111',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '16951,97',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '29362',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '11088190,70',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '17454',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '5504449,84',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1285',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '372177,70',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '39587',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '16560667,65',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '82881',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '23554823,86',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1997',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '442049',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '160553121,43',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1211924',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '469094377,75',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1054823',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '357439826,76',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '55450',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '16769883,49',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '849116',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '438508650,32',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '523608',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '203301535,01',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '28017',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '10215381,74',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '137319',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '51234804,10',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1117512',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '321292599,07',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '53121',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '15942660,95',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '130990',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '55742116,51',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '231526',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '75416182,69',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '14162',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '4914543,28',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '4539',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '1693297,46',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '4387',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '1443480,37',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '13522',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '5164306,25',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '12831',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '3357183,55',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '8142',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '1588326,66',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1587',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '375708,85',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '152823',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '52857312,80',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '250870',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '72868394,13',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1998',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '224768',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '110587766,73',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1247502',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '527923347,20',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1069354',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '396696250,91',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '14449',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '4566591,12',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '917162',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '506314578,89',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '588237',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '242081640,37',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '69032',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '43742141,27',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '154584',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '63096517,66',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1271809',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '401430585,97',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '61502',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '23281442,45',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '141269',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '68271511,22',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '247996',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '90810283,42',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '8775',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '3811051,35',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '107586',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '32320811,56',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '115997',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '35391160,10',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '172598',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '87412077,91',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '12514',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '3565426,50',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '7656',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '1693900,23',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '459',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '126524,02',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '50990',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '16000720,13',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '62198',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '14053750,37',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '1999',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '42803',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '8544667,79',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1018741',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '510203356,27',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '908683',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '390732708,16',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '8420',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '3878868,15',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '792055',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '484532302,24',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '507598',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '237233416,02',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '12934',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '5217379,74',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '155559',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '67007482,50',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '1326161',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '438615887,06',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Doméstico',
#    'Categoria até 2006': 'Doméstico',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '52782',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '17361446,48',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '147572',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '78448654,49',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '260550',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '105947491,85',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Facultativo',
#    'Categoria até 2006': 'Facultativo',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '8257',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '3381403,33',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '370463',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '84275461,21',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '318839',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '71433039,89',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '108665',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '40691243,33',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '12173',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '3696118,99',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '8235',
#    'Sexo': 'Feminino',
#    'Valor da Contribuição - R$': '1913432,18',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Segurado Especial',
#    'Categoria até 2006': 'Segurado Especial',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '327',
#    'Sexo': 'Ignorado',
#    'Valor da Contribuição - R$': '76930,49',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '0,00',
#    'Qtde Outros Contribuintes': '107590',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '59637669,50',
#    'Vlr Sal Contribuição - R$': '0,00'}},
#  {'node': {'Ano': '2000',
#    'Categoria': 'Ignorada',
#    'Categoria até 2006': 'Ignorada',
# ...
#    'Qtde Outros Contribuintes': '14',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '35177,19',
#    'Vlr Sal Contribuição - R$': '280490,29'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '3,67',
#    'Qtde Outros Contribuintes': '4',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '11942,33',
#    'Vlr Sal Contribuição - R$': '108566,53'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '7,58',
#    'Qtde Outros Contribuintes': '8',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '26485,83',
#    'Vlr Sal Contribuição - R$': '240780,04'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '18,83',
#    'Qtde Outros Contribuintes': '19',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '75131,32',
#    'Vlr Sal Contribuição - R$': '595381,16'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '4,00',
#    'Qtde Outros Contribuintes': '4',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '23986,71',
#    'Vlr Sal Contribuição - R$': '142514,86'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '160,75',
#    'Qtde Outros Contribuintes': '552',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '80274,64',
#    'Vlr Sal Contribuição - R$': '726870,44'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '197,25',
#    'Qtde Outros Contribuintes': '231',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '105872,63',
#    'Vlr Sal Contribuição - R$': '955651,64'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '51,33',
#    'Qtde Outros Contribuintes': '64',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '53911,59',
#    'Vlr Sal Contribuição - R$': '413130,30'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '27,50',
#    'Qtde Outros Contribuintes': '34',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '40358,86',
#    'Vlr Sal Contribuição - R$': '347375,88'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '11,92',
#    'Qtde Outros Contribuintes': '15',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '22731,78',
#    'Vlr Sal Contribuição - R$': '200761,46'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '6,25',
#    'Qtde Outros Contribuintes': '9',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '16444,41',
#    'Vlr Sal Contribuição - R$': '119114,45'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '5,25',
#    'Qtde Outros Contribuintes': '6',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '13383,68',
#    'Vlr Sal Contribuição - R$': '121668,83'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '11,08',
#    'Qtde Outros Contribuintes': '12',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '31398,83',
#    'Vlr Sal Contribuição - R$': '241718,39'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '9,33',
#    'Qtde Outros Contribuintes': '10',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '28830,09',
#    'Vlr Sal Contribuição - R$': '215233,06'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '5,00',
#    'Qtde Outros Contribuintes': '5',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '16281,23',
#    'Vlr Sal Contribuição - R$': '147274,35'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '12,75',
#    'Qtde Outros Contribuintes': '13',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '50523,11',
#    'Vlr Sal Contribuição - R$': '406328,54'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '6,00',
#    'Qtde Outros Contribuintes': '6',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '37474,68',
#    'Vlr Sal Contribuição - R$': '236040,00'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '5,00',
#    'Qtde Outros Contribuintes': '5',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '38574,49',
#    'Vlr Sal Contribuição - R$': '291965,88'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '138,58',
#    'Qtde Outros Contribuintes': '531',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '72681,05',
#    'Vlr Sal Contribuição - R$': '655859,13'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '168,75',
#    'Qtde Outros Contribuintes': '205',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '92202,61',
#    'Vlr Sal Contribuição - R$': '832989,19'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '48,25',
#    'Qtde Outros Contribuintes': '61',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '52640,43',
#    'Vlr Sal Contribuição - R$': '411449,69'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '21,42',
#    'Qtde Outros Contribuintes': '27',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '32772,57',
#    'Vlr Sal Contribuição - R$': '279213,75'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '8,33',
#    'Qtde Outros Contribuintes': '12',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '18607,19',
#    'Vlr Sal Contribuição - R$': '139140,47'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '10,33',
#    'Qtde Outros Contribuintes': '14',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '26157,51',
#    'Vlr Sal Contribuição - R$': '230431,81'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '7,83',
#    'Qtde Outros Contribuintes': '10',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '21693,09',
#    'Vlr Sal Contribuição - R$': '188263,97'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '7,83',
#    'Qtde Outros Contribuintes': '9',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '23232,63',
#    'Vlr Sal Contribuição - R$': '200569,21'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '4,67',
#    'Qtde Outros Contribuintes': '5',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '14953,42',
#    'Vlr Sal Contribuição - R$': '123674,65'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '5,33',
#    'Qtde Outros Contribuintes': '6',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '19868,76',
#    'Vlr Sal Contribuição - R$': '153073,53'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '24,00',
#    'Qtde Outros Contribuintes': '24',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '92657,59',
#    'Vlr Sal Contribuição - R$': '745112,80'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '9,00',
#    'Qtde Outros Contribuintes': '9',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '57345,94',
#    'Vlr Sal Contribuição - R$': '311618,69'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '1,00',
#    'Qtde Outros Contribuintes': '1',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '7177,31',
#    'Vlr Sal Contribuição - R$': '35886,55'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '140,67',
#    'Qtde Outros Contribuintes': '500',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '67872,13',
#    'Vlr Sal Contribuição - R$': '613219,43'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '145,08',
#    'Qtde Outros Contribuintes': '172',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '76728,49',
#    'Vlr Sal Contribuição - R$': '689933,42'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '53,67',
#    'Qtde Outros Contribuintes': '65',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '54834,06',
#    'Vlr Sal Contribuição - R$': '410153,41'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '17,33',
#    'Qtde Outros Contribuintes': '21',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '25647,74',
#    'Vlr Sal Contribuição - R$': '223342,93'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '9,58',
#    'Qtde Outros Contribuintes': '12',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '18895,09',
#    'Vlr Sal Contribuição - R$': '145321,79'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '12,58',
#    'Qtde Outros Contribuintes': '15',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '28270,39',
#    'Vlr Sal Contribuição - R$': '238754,47'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '9,75',
#    'Qtde Outros Contribuintes': '12',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '25821,14',
#    'Vlr Sal Contribuição - R$': '208083,06'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '13,92',
#    'Qtde Outros Contribuintes': '16',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '40085,52',
#    'Vlr Sal Contribuição - R$': '344206,09'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '6,33',
#    'Qtde Outros Contribuintes': '7',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '20730,93',
#    'Vlr Sal Contribuição - R$': '188462,83'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '6,58',
#    'Qtde Outros Contribuintes': '7',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '22546,36',
#    'Vlr Sal Contribuição - R$': '191423,52'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '28,58',
#    'Qtde Outros Contribuintes': '29',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '107742,49',
#    'Vlr Sal Contribuição - R$': '899082,26'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '4,00',
#    'Qtde Outros Contribuintes': '4',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '26344,28',
#    'Vlr Sal Contribuição - R$': '131721,40'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '1,00',
#    'Qtde Outros Contribuintes': '1',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '7024,36',
#    'Vlr Sal Contribuição - R$': '34794,57'}},
#  {'node': {'Ano': '2006',
#    'Categoria': 'Individual',
#    'Categoria até 2006': 'Individual',
#    'Estatística Out Contribuintes': 'Qtde Outros Contribuintes',
#    'Número Médio Mensal Out Contri': '145,75',
#    'Qtde Outros Contribuintes': '500',
#    'Sexo': 'Masculino',
#    'Valor da Contribuição - R$': '73403,72',
#    'Vlr Sal Contribuição - R$': '666242,16'}},
#  ...]
